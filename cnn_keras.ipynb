# %%
from keras import layers
from keras import models

model=models.Sequential()
model.add(layers.Conv2D(32,(5,5),activation='relu',input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2,2)))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 32)        832
#
#  max_pooling2d (MaxPooling2  (None, 12, 12, 32)        0
#  D)
#
# =================================================================
# Total params: 832 (3.25 KB)
# Trainable params: 832 (3.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model=models.Sequential()
model.add(layers.Conv2D(32,(5,5),activation='relu',input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(5,5),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 24, 24, 32)        832
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 64)          51264
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 64)          0
#  g2D)
#
# =================================================================
# Total params: 52096 (203.50 KB)
# Trainable params: 52096 (203.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model=models.Sequential()

model.add(layers.Conv2D(32,(5,5),activation='relu',input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(64,(5,5),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Flatten())
model.add(layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 24, 24, 32)        832
#
#  max_pooling2d_3 (MaxPoolin  (None, 12, 12, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 64)          51264
#
#  max_pooling2d_4 (MaxPoolin  (None, 4, 4, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 10)                10250
#
# =================================================================
# Total params: 62346 (243.54 KB)
# Trainable params: 62346 (243.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.datasets import mnist
from keras.utils import to_categorical

(train_images, train_labels), (test_images, test_labels)=mnist.load_data()

train_images=train_images.reshape((60000,28,28,1))
train_images=train_images.astype('float32')/255

test_images=test_images.reshape((10000,28,28,1))
test_images=test_images.astype('float32')/255

train_labels=to_categorical(train_labels)
test_labels=to_categorical(test_labels)

batch_size=100
epochs=10

model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

model.fit(train_images, train_labels,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1)
# Out:
# Epoch 1/10
# 600/600 [==============================] - 62s 101ms/step - loss: 0.9508 - accuracy: 0.7556
# Epoch 2/10
# 600/600 [==============================] - 64s 106ms/step - loss: 0.2696 - accuracy: 0.9207
# Epoch 3/10
# 600/600 [==============================] - 62s 104ms/step - loss: 0.1946 - accuracy: 0.9425
# Epoch 4/10
# 600/600 [==============================] - 61s 101ms/step - loss: 0.1546 - accuracy: 0.9542
# Epoch 5/10
# 600/600 [==============================] - 61s 102ms/step - loss: 0.1297 - accuracy: 0.9625
# Epoch 6/10
# 600/600 [==============================] - 62s 103ms/step - loss: 0.1128 - accuracy: 0.9676
# Epoch 7/10
# 600/600 [==============================] - 62s 102ms/step - loss: 0.1008 - accuracy: 0.9706
# Epoch 8/10
# 600/600 [==============================] - 60s 100ms/step - loss: 0.0925 - accuracy: 0.9726
# Epoch 9/10
# 600/600 [==============================] - 60s 100ms/step - loss: 0.0849 - accuracy: 0.9753
# Epoch 10/10
# 600/600 [==============================] - 63s 105ms/step - loss: 0.0789 - accuracy: 0.9768
